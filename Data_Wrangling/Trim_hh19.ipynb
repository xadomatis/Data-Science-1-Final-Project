# %% [markdown]
# I'm going to keep this one short, because my intention is to simplify

# %%
import pandas as pd

# %%
hh = pd.read_csv("/Users/xavier/Desktop/DSPP/DS/Project/2019_Survey/hh2019_analys.csv", low_memory=False)

# %%
hh
# Out:
#                 hrhhid  hrmonth  hryear4  hurespli  hufinal  hulangcode  \
# 0      105570010074613        6     2019         2      201           0
# 1      710004140617571        6     2019         1      201           0
# 2      104430010061644        6     2019         1      201           0
# 3      661144001440003        6     2019         1      201           0
# 4      164400364411000        6     2019         1      201           0
# ...                ...      ...      ...       ...      ...         ...
# 70198  521069004350265        6     2019         2      201           0
# 70199  710004565255836        6     2019         1      218           0
# 70200  614830557641005        6     2019        -1      216           0
# 70201  561163008550474        6     2019        -1      216           0
# 70202  654240932181005        6     2019        -1      218           0
#
#        hetenure  hehousut  hetelhhd  hetelavl  ...  repwgt151   repwgt152  \
# ...

# %%
hh_cut = hh[['hrhhid','hrhhid2','gestfips','msa13','gtcbsast','hagele15','hbnkprev','hhincome','hhtenure','hhtype','hryear4','hunbnk','prtage','pdisabl_age25to64','peducgrp','pempstat','pnativ','praceeth3','hincvolv2','hintaccv2','hbnkint','hunbnkrmv4','hhfamtyp','hsupresp','hsupwgtk']].copy()

# %%
hh_cut.to_csv("/Users/xavier/Desktop/DSPP/DS/Data-Science-1-Final-Project/Data_Wrangling/hh_2019.csv")
